# %% [markdown]
# # Analyse des resultats des test de différentes structures de MLP sur le dataset Cifar-10

# %% [markdown]
# ### Informations

# %% [markdown]
# Dans ce notebook, nous allons analyser les resultats obtenus sur la première vague de tests de différentes structures et hyperparametres de MLP. Pour chaque un des tests menés, 20 modèles on été testés.

# %% [markdown]
# ## Preparation des outils

# %%
import pandas as pd

# %% [markdown]
# ## MLP 10 à 15 couches - 64 neurones par couche - Dropout - 200 epochs

# %%
history_csv_file = ".\\trained_models\\mlp\\tested_mlp_dropout_10_15_64_history.csv"
tests_history = pd.read_csv(history_csv_file, sep=";")

nb_epochs = 200

filtered_history = tests_history[tests_history.epochs == nb_epochs]

# %%
tests_history
# Out:
#     nb_couches                           profondeurs_couches  \
# 0           11              64 64 64 64 64 64 64 64 64 64 64
# 1           10                 64 64 64 64 64 64 64 64 64 64
# 2           15  64 64 64 64 64 64 64 64 64 64 64 64 64 64 64
# 3           13        64 64 64 64 64 64 64 64 64 64 64 64 64
# 4           13        64 64 64 64 64 64 64 64 64 64 64 64 64
# 5           13        64 64 64 64 64 64 64 64 64 64 64 64 64
# 6           11              64 64 64 64 64 64 64 64 64 64 64
# 7           11              64 64 64 64 64 64 64 64 64 64 64
# 8           10                 64 64 64 64 64 64 64 64 64 64
# 9           15  64 64 64 64 64 64 64 64 64 64 64 64 64 64 64
# 10          11              64 64 64 64 64 64 64 64 64 64 64
# 11          12           64 64 64 64 64 64 64 64 64 64 64 64
# 12          13        64 64 64 64 64 64 64 64 64 64 64 64 64
# 13          10                 64 64 64 64 64 64 64 64 64 64
# 14          10                 64 64 64 64 64 64 64 64 64 64
# 15          11              64 64 64 64 64 64 64 64 64 64 64
# 16          10                 64 64 64 64 64 64 64 64 64 64
# 17          14     64 64 64 64 64 64 64 64 64 64 64 64 64 64
# 18          13        64 64 64 64 64 64 64 64 64 64 64 64 64
# 19          15  64 64 64 64 64 64 64 64 64 64 64 64 64 64 64
# 20          12           64 64 64 64 64 64 64 64 64 64 64 64
#
#    activation_couches activation_output  dropout  nb_dropout  \
# 0                selu           softmax     True           6
# 1             softmax           softmax     True           5
# 2                selu           softmax     True          11
# 3                relu           softmax     True          10
# 4                selu           softmax     True           4
# 5                selu           softmax     True           2
# 6            softplus           softmax     True           5
# 7             softmax           softmax     True           9
# 8                relu           softmax     True           4
# 9                selu           softmax     True          15
# 10            softmax           softmax     True           9
# 11               selu           softmax     True           1
# 12            softmax           softmax     True           6
# 13               relu           softmax     True           3
# 14               selu           softmax     True           1
# 15               selu           softmax     True           9
# 16               relu           softmax     True           8
# 17           softplus           softmax     True           3
# 18            softmax           softmax     True           4
# 19               selu           softmax     True           7
# 20               relu           softmax     True          12
#
#                          indexes_dropout  valeur_dropout  l1l2_couches  \
# 0                           5 11 4 9 5 2             0.2         False
# 1                             10 7 6 7 2             0.2         False
# 2               9 9 9 4 14 7 11 6 14 5 7             0.3         False
# 3                  5 11 2 1 7 8 10 6 5 8             0.2         False
# 4                               5 3 13 8             0.1         False
# 5                                   10 2             0.3         False
# 6                             4 1 6 11 2             0.1         False
# 7                    8 11 2 11 4 5 9 8 5             0.2         False
# 8                                3 2 7 3             0.2         False
# 9   1 4 5 10 14 4 9 11 4 10 11 9 7 15 11             0.2         False
# 10                   8 4 6 7 10 10 4 8 7             0.3         False
# 11                                    12             0.2         False
# 12                       13 10 13 8 7 10             0.1         False
# 13                                 5 7 7             0.3         False
# 14                                     8             0.3         False
# 15                    8 6 5 9 1 7 11 3 7             0.2         False
# 16                       1 1 7 2 4 1 5 7             0.3         False
# 17                                9 8 10             0.2         False
# 18                              7 4 13 1             0.3         False
# 19                       15 6 13 7 3 9 9             0.3         False
# 20             8 3 10 2 11 8 4 6 6 5 4 1             0.1         False
#
#     l1l2_output  ...  nb_l1l2  indexes_l1l2                             loss  \
# 0         False  ...        0           NaN  sparse_categorical_crossentropy
# 1         False  ...        0           NaN  sparse_categorical_crossentropy
# 2         False  ...        0           NaN  sparse_categorical_crossentropy
# 3         False  ...        0           NaN  sparse_categorical_crossentropy
# 4         False  ...        0           NaN  sparse_categorical_crossentropy
# 5         False  ...        0           NaN  sparse_categorical_crossentropy
# 6         False  ...        0           NaN  sparse_categorical_crossentropy
# 7         False  ...        0           NaN  sparse_categorical_crossentropy
# 8         False  ...        0           NaN  sparse_categorical_crossentropy
# 9         False  ...        0           NaN  sparse_categorical_crossentropy
# 10        False  ...        0           NaN  sparse_categorical_crossentropy
# 11        False  ...        0           NaN  sparse_categorical_crossentropy
# 12        False  ...        0           NaN  sparse_categorical_crossentropy
# 13        False  ...        0           NaN  sparse_categorical_crossentropy
# 14        False  ...        0           NaN  sparse_categorical_crossentropy
# 15        False  ...        0           NaN  sparse_categorical_crossentropy
# 16        False  ...        0           NaN  sparse_categorical_crossentropy
# 17        False  ...        0           NaN  sparse_categorical_crossentropy
# 18        False  ...        0           NaN  sparse_categorical_crossentropy
# 19        False  ...        0           NaN  sparse_categorical_crossentropy
# 20        False  ...        0           NaN  sparse_categorical_crossentropy
#
#     optimizer                      metrics epochs model_id  train_accuracy  \
# 0        Adam  sparse_categorical_accuracy     10  8129637         0.11512
# 1        Adam  sparse_categorical_accuracy     10  4021453         0.10000
# 2        Adam  sparse_categorical_accuracy     10  4766037         0.12604
# 3        Adam  sparse_categorical_accuracy     10  3426013         0.10546
# 4        Adam  sparse_categorical_accuracy     10  8776439         0.21600
# 5        Adam  sparse_categorical_accuracy     10  2864880         0.17044
# 6        Adam  sparse_categorical_accuracy     10  3567363         0.18598
# 7        Adam  sparse_categorical_accuracy     10  8940921         0.10000
# 8        Adam  sparse_categorical_accuracy     10  9031792         0.11496
# 9        Adam  sparse_categorical_accuracy     10  5444023         0.15840
# 10       Adam  sparse_categorical_accuracy     10  1162508         0.10000
# 11       Adam  sparse_categorical_accuracy     10  4616454         0.28708
# 12       Adam  sparse_categorical_accuracy     10  8541289         0.10000
# 13       Adam  sparse_categorical_accuracy     10  9481383         0.13136
# 14       Adam  sparse_categorical_accuracy     10  7956539         0.24092
# 15       Adam  sparse_categorical_accuracy     10  5571556         0.10000
# 16       Adam  sparse_categorical_accuracy     10  8552419         0.10000
# 17       Adam  sparse_categorical_accuracy     10  8914697         0.22690
# 18       Adam  sparse_categorical_accuracy     10  5092869         0.10000
# 19       Adam  sparse_categorical_accuracy     10  2810202         0.09566
# 20       Adam  sparse_categorical_accuracy     10  6649245         0.12064
#
#     val_accuracy   dossier
# 0         0.1158  20200122
# 1         0.1000  20200122
# 2         0.1272  20200122
# 3         0.1058  20200122
# 4         0.2156  20200122
# 5         0.1689  20200122
# 6         0.1846  20200122
# 7         0.1000  20200122
# 8         0.1159  20200122
# 9         0.1658  20200122
# 10        0.1000  20200122
# 11        0.2839  20200122
# 12        0.1000  20200122
# 13        0.1271  20200122
# 14        0.2433  20200122
# 15        0.1001  20200122
# 16        0.1000  20200122
# 17        0.2247  20200122
# 18        0.1000  20200122
# 19        0.0924  20200122
# 20        0.1221  20200122
#
# [21 rows x 22 columns]
